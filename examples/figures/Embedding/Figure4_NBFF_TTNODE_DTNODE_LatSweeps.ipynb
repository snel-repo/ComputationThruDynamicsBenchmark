# %%
import matplotlib.pyplot as plt

import numpy as np
import os
from ctd.comparison.analysis.tt.tt import Analysis_TT 
from ctd.comparison.analysis.dd.dd import Analysis_DD
# Import pca
import dotenv
from ctd.comparison.comparison import Comparison
import torch
from sklearn.decomposition import PCA

dotenv.load_dotenv(dotenv.find_dotenv())
# Out:
# True

# %%
HOME_DIR = os.environ['HOME_DIR']
print(HOME_DIR)

pathTT = HOME_DIR + 'content/trained_models/task-trained/20240503_Fig1_NBFF_NoisyGRU/max_epochs=500 n_samples=1000 latent_size=64 seed=0 learning_rate=0.001/'
an_TT = Analysis_TT(run_name = "TT", filepath = pathTT)


path_NODE_Sweep = pathTT + "20240508_Fig3_NBFF_NODE_TT_GRU_LatSweep/"
subfolders_NODE = [f.path for f in os.scandir(path_NODE_Sweep) if f.is_dir()]
# Out:
# /home/csverst/Github/CtDBenchmark/

# %%
comparison = Comparison(comparison_tag="Figure1NBFF_TTGRU_DTNODE_Sweep")
comparison.load_analysis(an_TT, reference_analysis=True, group = "TT")

for subfolder in subfolders_NODE:
    
    final_folder = subfolder.split("/")[-1]
    subfolder = subfolder + "/"
    print(final_folder)
    # Find the latent size in the folder name
    latent_size = int(final_folder.split("latent_size=")[1].split(" ")[0])

    analysis_GRU = Analysis_DD(run_name = f"NODE_{latent_size}", filepath = subfolder, model_type = "SAE")
    comparison.load_analysis(analysis_GRU, group = f"NODE_{latent_size}")

comparison.regroup()
# Out:
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=0 max_epochs=1000 latent_size=12
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=1 max_epochs=1000 latent_size=8
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=0 max_epochs=1000 latent_size=3
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=3 max_epochs=1000 latent_size=3
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=2 max_epochs=1000 latent_size=3
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=2 max_epochs=1000 latent_size=12
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=2 max_epochs=1000 latent_size=5
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=3 max_epochs=1000 latent_size=12
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=2 max_epochs=1000 latent_size=8
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=3 max_epochs=1000 latent_size=8
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=3 max_epochs=1000 latent_size=5
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=1 max_epochs=1000 latent_size=5
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=0 max_epochs=1000 latent_size=8
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=1 max_epochs=1000 latent_size=12
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=1 max_epochs=1000 latent_size=3
# gen_model=NoisyGRU_RNN prefix=20240503_Fig1_NBFF_NoisyGRU seed=4 max_epochs=1000 latent_size=3

# %%
plot_dict = {
    "save_pdf": True,
    "ax_lim": [0.15, 1.05],
    "marker": "x",
}
comparison.compare_rate_state_r2(plot_dict=plot_dict)
# Out:
# Working on 1 of 17: NODE_12
# Group: NODE_12
# Rate R2: 0.8903295205392009
# State R2: 0.8908571220679811
# Working on 2 of 17: NODE_12
# Group: NODE_12
# Rate R2: 0.8901409340223804
# State R2: 0.9019295162857396
# Working on 3 of 17: NODE_12
# Group: NODE_12
# Rate R2: 0.8911877883362967
# State R2: 0.9414880964044492
# Working on 4 of 17: NODE_12
# Group: NODE_12
# Rate R2: 0.8848136462072752
# State R2: 0.9043745427611062
# Working on 5 of 17: NODE_3
# Group: NODE_3
# Rate R2: 0.770511469046116
# State R2: 0.9697211966752167
# Working on 6 of 17: NODE_3
# Group: NODE_3
# Rate R2: 0.7691611701703555
# State R2: 0.96620802174188
# Working on 7 of 17: NODE_3
# Group: NODE_3
# Rate R2: 0.7666871026010817
# State R2: 0.9670773469207945
# Working on 8 of 17: NODE_3
# Group: NODE_3
# Rate R2: 0.761457283589325
# State R2: 0.9588954263651631
# Working on 9 of 17: NODE_3
# Group: NODE_3
# Rate R2: 0.7624173552639022
# State R2: 0.9634157602577389
# Working on 10 of 17: NODE_5
# Group: NODE_5
# Rate R2: 0.8402544754550066
# State R2: 0.9671556696399048
# Working on 11 of 17: NODE_5
# Group: NODE_5
# Rate R2: 0.8388493529978979
# State R2: 0.9683256859994811
# Working on 12 of 17: NODE_5
# Group: NODE_5
# Rate R2: 0.829019584129871
# State R2: 0.9572171478208688
# Working on 13 of 17: NODE_8
# Group: NODE_8
# Rate R2: 0.8773270857558951
# State R2: 0.9649630738612681
# Working on 14 of 17: NODE_8
# Group: NODE_8
# Rate R2: 0.8858402798647138
# State R2: 0.9619458742279606
# Working on 15 of 17: NODE_8
# Group: NODE_8
# Rate R2: 0.8872399656316842
# State R2: 0.9685182949696786
# Working on 16 of 17: NODE_8
# Group: NODE_8
# Rate R2: 0.88683279556047
# State R2: 0.9669862422684276
# Working on 17 of 17: TT
# Group: TT
# array([[0.89032952, 0.89085712],
#        [0.89014093, 0.90192952],
#        [0.89118779, 0.9414881 ],
#        [0.88481365, 0.90437454],
#        [0.77051147, 0.9697212 ],
#        [0.76916117, 0.96620802],
#        [0.7666871 , 0.96707735],
#        [0.76145728, 0.95889543],
#        [0.76241736, 0.96341576],
#        [0.84025448, 0.96715567],
#        [0.83884935, 0.96832569],
#        [0.82901958, 0.95721715],
#        [0.87732709, 0.96496307],
#        [0.88584028, 0.96194587],
#        [0.88723997, 0.96851829],
#        [0.8868328 , 0.96698624],
#        [0.        , 0.        ]])

# %%
fpsTT = an_TT.plot_fps(
    inputs = torch.zeros(3),
    max_iters = 40000,
    learning_rate =5e-3,
)
# Out:
# Iteration 500/40000
# q = 4.22E-04 +/- 1.70E-03
# dq = 1.44E-06 +/- 6.13E-06
#
# Iteration 1000/40000
# q = 1.30E-04 +/- 5.07E-04
# dq = 2.25E-07 +/- 9.89E-07
#
# Iteration 1500/40000
# q = 6.43E-05 +/- 2.29E-04
# dq = 7.78E-08 +/- 3.23E-07
#
# Iteration 2000/40000
# q = 3.82E-05 +/- 1.21E-04
# dq = 3.90E-08 +/- 1.46E-07
#
# Iteration 2500/40000
# q = 2.49E-05 +/- 7.05E-05
# dq = 2.54E-08 +/- 7.43E-08
#
# Iteration 3000/40000
# q = 1.74E-05 +/- 4.52E-05
# dq = 2.01E-08 +/- 4.83E-08
#
# Iteration 3500/40000
# q = 1.27E-05 +/- 3.10E-05
# dq = 2.08E-08 +/- 5.18E-08
#
# Iteration 4000/40000
# q = 9.51E-06 +/- 2.23E-05
# dq = 2.58E-08 +/- 7.12E-08
#
# Iteration 4500/40000
# q = 7.27E-06 +/- 1.65E-05
# dq = 3.08E-08 +/- 9.73E-08
#
# Iteration 5000/40000
# q = 5.70E-06 +/- 1.26E-05
# dq = 5.10E-08 +/- 1.30E-07
#
# Iteration 5500/40000
# q = 4.52E-06 +/- 9.86E-06
# dq = 6.88E-08 +/- 2.02E-07
#
# Iteration 6000/40000
# q = 3.62E-06 +/- 7.82E-06
# dq = 6.98E-08 +/- 1.83E-07
#
# Iteration 6500/40000
# q = 3.01E-06 +/- 6.29E-06
# dq = 9.30E-08 +/- 2.33E-07
#
# Iteration 7000/40000
# q = 2.55E-06 +/- 5.10E-06
# dq = 1.25E-07 +/- 2.80E-07
#
# Iteration 7500/40000
# q = 2.21E-06 +/- 4.15E-06
# dq = 1.43E-07 +/- 3.31E-07
#
# Iteration 8000/40000
# q = 1.86E-06 +/- 3.33E-06
# dq = 1.36E-07 +/- 2.99E-07
#
# Iteration 8500/40000
# q = 1.67E-06 +/- 2.77E-06
# dq = 1.58E-07 +/- 3.47E-07
#
# Iteration 9000/40000
# q = 1.46E-06 +/- 2.39E-06
# dq = 1.52E-07 +/- 3.10E-07
#
# Iteration 9500/40000
# q = 1.32E-06 +/- 2.09E-06
# dq = 1.58E-07 +/- 3.31E-07
#
# Iteration 10000/40000
# q = 1.14E-06 +/- 1.81E-06
# dq = 1.52E-07 +/- 3.44E-07
#
# Iteration 10500/40000
# q = 1.14E-06 +/- 1.81E-06
# dq = 1.63E-07 +/- 3.53E-07
#
# Iteration 11000/40000
# q = 1.01E-06 +/- 1.52E-06
# dq = 1.87E-07 +/- 4.62E-07
#
# Iteration 11500/40000
# q = 1.01E-06 +/- 1.58E-06
# dq = 1.83E-07 +/- 3.51E-07
#
# Iteration 12000/40000
# q = 9.99E-07 +/- 1.63E-06
# dq = 1.71E-07 +/- 3.50E-07
#
# Iteration 12500/40000
# q = 8.11E-07 +/- 1.33E-06
# dq = 1.58E-07 +/- 3.66E-07
#
# Iteration 13000/40000
# q = 1.00E-06 +/- 1.70E-06
# dq = 1.94E-07 +/- 4.00E-07
#
# Iteration 13500/40000
# q = 9.06E-07 +/- 1.47E-06
# dq = 1.71E-07 +/- 3.36E-07
#
# Iteration 14000/40000
# q = 8.33E-07 +/- 1.31E-06
# dq = 1.73E-07 +/- 3.48E-07
#
# Iteration 14500/40000
# q = 9.11E-07 +/- 1.50E-06
# dq = 1.82E-07 +/- 3.73E-07
#
# Iteration 15000/40000
# q = 8.42E-07 +/- 1.46E-06
# dq = 1.74E-07 +/- 4.08E-07
#
# Iteration 15500/40000
# q = 8.40E-07 +/- 1.42E-06
# dq = 1.74E-07 +/- 3.45E-07
#
# Iteration 16000/40000
# q = 8.14E-07 +/- 1.46E-06
# dq = 1.69E-07 +/- 3.40E-07
#
# Iteration 16500/40000
# q = 8.34E-07 +/- 1.49E-06
# dq = 1.76E-07 +/- 3.69E-07
#
# Iteration 17000/40000
# q = 7.29E-07 +/- 1.35E-06
# dq = 1.64E-07 +/- 3.61E-07
#
# Iteration 17500/40000
# q = 7.60E-07 +/- 1.40E-06
# dq = 1.67E-07 +/- 3.64E-07
#
# Iteration 18000/40000
# q = 8.08E-07 +/- 1.60E-06
# dq = 1.63E-07 +/- 3.44E-07
#
# Iteration 18500/40000
# q = 7.42E-07 +/- 1.38E-06
# dq = 1.75E-07 +/- 3.90E-07
#
# Iteration 19000/40000
# q = 7.40E-07 +/- 1.36E-06
# dq = 1.65E-07 +/- 3.35E-07
#
# Iteration 19500/40000
# q = 6.70E-07 +/- 1.22E-06
# dq = 1.59E-07 +/- 3.40E-07
#
# Iteration 20000/40000
# q = 7.49E-07 +/- 1.43E-06
# dq = 1.64E-07 +/- 3.72E-07
#
# Iteration 20500/40000
# q = 7.01E-07 +/- 1.23E-06
# dq = 1.72E-07 +/- 3.66E-07
#
# Iteration 21000/40000
# q = 7.56E-07 +/- 1.44E-06
# dq = 1.68E-07 +/- 3.63E-07
#
# Iteration 21500/40000
# q = 6.64E-07 +/- 1.27E-06
# dq = 1.51E-07 +/- 3.19E-07
#
# Iteration 22000/40000
# q = 7.01E-07 +/- 1.28E-06
# dq = 1.73E-07 +/- 3.65E-07
#
# Iteration 22500/40000
# q = 7.88E-07 +/- 1.52E-06
# dq = 1.76E-07 +/- 4.03E-07
#
# Iteration 23000/40000
# q = 7.37E-07 +/- 1.35E-06
# dq = 1.75E-07 +/- 3.82E-07
#
# Iteration 23500/40000
# q = 7.78E-07 +/- 1.55E-06
# dq = 1.65E-07 +/- 3.36E-07
#
# Iteration 24000/40000
# q = 8.23E-07 +/- 1.56E-06
# dq = 1.86E-07 +/- 3.95E-07
#
# Iteration 24500/40000
# q = 7.00E-07 +/- 1.32E-06
# dq = 1.61E-07 +/- 3.48E-07
#
# Iteration 25000/40000
# q = 6.92E-07 +/- 1.24E-06
# dq = 1.62E-07 +/- 3.21E-07
#
# Iteration 25500/40000
# q = 7.06E-07 +/- 1.41E-06
# dq = 1.64E-07 +/- 3.90E-07
#
# Iteration 26000/40000
# q = 6.77E-07 +/- 1.42E-06
# dq = 1.40E-07 +/- 2.77E-07
#
# Iteration 26500/40000
# q = 6.77E-07 +/- 1.35E-06
# dq = 1.68E-07 +/- 3.76E-07
#
# Iteration 27000/40000
# q = 6.03E-07 +/- 1.25E-06
# dq = 1.52E-07 +/- 3.54E-07
#
# Iteration 27500/40000
# q = 6.70E-07 +/- 1.37E-06
# dq = 1.60E-07 +/- 3.35E-07
#
# Iteration 28000/40000
# q = 7.35E-07 +/- 1.46E-06
# dq = 1.60E-07 +/- 3.40E-07
#
# Iteration 28500/40000
# q = 6.47E-07 +/- 1.28E-06
# dq = 1.59E-07 +/- 3.51E-07
#
# Iteration 29000/40000
# q = 7.49E-07 +/- 1.49E-06
# dq = 1.89E-07 +/- 4.27E-07
#
# Iteration 29500/40000
# q = 6.54E-07 +/- 1.17E-06
# dq = 1.61E-07 +/- 3.39E-07
#
# Iteration 30000/40000
# q = 6.19E-07 +/- 1.17E-06
# dq = 1.62E-07 +/- 3.61E-07
#
# Iteration 30500/40000
# q = 6.94E-07 +/- 1.33E-06
# dq = 1.63E-07 +/- 3.48E-07
#
# Iteration 31000/40000
# q = 7.19E-07 +/- 1.50E-06
# dq = 1.51E-07 +/- 3.22E-07
#
# Iteration 31500/40000
# q = 6.80E-07 +/- 1.30E-06
# dq = 1.59E-07 +/- 3.33E-07
#
# Iteration 32000/40000
# q = 6.80E-07 +/- 1.41E-06
# dq = 1.65E-07 +/- 3.67E-07
#
# Iteration 32500/40000
# q = 6.69E-07 +/- 1.34E-06
# dq = 1.62E-07 +/- 3.76E-07
#
# Iteration 33000/40000
# q = 6.42E-07 +/- 1.18E-06
# dq = 1.75E-07 +/- 4.14E-07
#
# Iteration 33500/40000
# q = 7.43E-07 +/- 1.38E-06
# dq = 1.95E-07 +/- 4.66E-07
#
# Iteration 34000/40000
# q = 7.85E-07 +/- 1.56E-06
# dq = 1.79E-07 +/- 4.08E-07
#
# Iteration 34500/40000
# q = 6.93E-07 +/- 1.35E-06
# dq = 1.81E-07 +/- 3.96E-07
#
# Iteration 35000/40000
# q = 6.54E-07 +/- 1.35E-06
# dq = 1.60E-07 +/- 3.54E-07
#
# Iteration 35500/40000
# q = 6.95E-07 +/- 1.44E-06
# dq = 1.69E-07 +/- 3.60E-07
#
# Iteration 36000/40000
# q = 7.37E-07 +/- 1.53E-06
# dq = 1.71E-07 +/- 3.56E-07
#
# Iteration 36500/40000
# q = 7.26E-07 +/- 1.42E-06
# dq = 1.90E-07 +/- 4.03E-07
#
# Iteration 37000/40000
# q = 6.47E-07 +/- 1.32E-06
# dq = 1.78E-07 +/- 4.22E-07
#
# Iteration 37500/40000
# q = 7.03E-07 +/- 1.30E-06
# dq = 1.84E-07 +/- 3.83E-07
#
# Iteration 38000/40000
# q = 7.24E-07 +/- 1.41E-06
# dq = 1.80E-07 +/- 3.75E-07
#
# Iteration 38500/40000
# q = 6.43E-07 +/- 1.38E-06
# dq = 1.51E-07 +/- 3.38E-07
#
# Iteration 39000/40000
# q = 6.32E-07 +/- 1.24E-06
# dq = 1.55E-07 +/- 3.34E-07
#
# Iteration 39500/40000
# q = 7.22E-07 +/- 1.46E-06
# dq = 1.88E-07 +/- 3.97E-07
#
# Iteration 40000/40000
# q = 6.34E-07 +/- 1.26E-06
# dq = 1.63E-07 +/- 3.40E-07
# Maximum iteration count reached. Terminating.
# Found 1024 unique fixed points.
# Decomposing Jacobians in a single batch.
# Sorting by Eigenvalue magnitude.

# %%
fpsDT_GRU = analysis_GRU.plot_fps(
    inputs = torch.zeros(3),
    max_iters = 40000,
    learning_rate =5e-3,
)
# Out:
# Iteration 500/40000
# q = 5.67E-07 +/- 7.80E-06
# dq = 3.92E-09 +/- 5.52E-08
#
# Iteration 1000/40000
# q = 1.77E-08 +/- 3.38E-07
# dq = 1.25E-10 +/- 2.49E-09
#
# Iteration 1500/40000
# q = 3.38E-09 +/- 9.47E-08
# dq = 4.05E-10 +/- 1.13E-08
#
# Iteration 2000/40000
# q = 1.12E-09 +/- 3.44E-08
# dq = 1.12E-11 +/- 1.68E-10
#
# Iteration 2500/40000
# q = 1.04E-08 +/- 3.21E-07
# dq = 4.38E-09 +/- 1.34E-07
#
# Iteration 3000/40000
# q = 1.28E-10 +/- 1.68E-09
# dq = 5.36E-11 +/- 8.59E-10
#
# Iteration 3500/40000
# q = 1.15E-08 +/- 3.22E-07
# dq = 9.70E-09 +/- 2.99E-07
#
# Iteration 4000/40000
# q = 1.45E-09 +/- 1.99E-08
# dq = 3.62E-10 +/- 4.52E-09
#
# Iteration 4500/40000
# q = 1.47E-09 +/- 1.45E-08
# dq = 6.42E-10 +/- 7.88E-09
#
# Iteration 5000/40000
# q = 1.86E-09 +/- 2.41E-08
# dq = 8.68E-10 +/- 8.24E-09
#
# Iteration 5500/40000
# q = 3.61E-09 +/- 4.21E-08
# dq = 8.39E-10 +/- 6.78E-09
#
# Iteration 6000/40000
# q = 2.15E-09 +/- 1.58E-08
# dq = 1.13E-09 +/- 7.91E-09
#
# Iteration 6500/40000
# q = 5.35E-09 +/- 4.66E-08
# dq = 2.13E-09 +/- 2.75E-08
#
# Iteration 7000/40000
# q = 5.16E-09 +/- 4.02E-08
# dq = 2.11E-09 +/- 1.45E-08
#
# Iteration 7500/40000
# q = 5.02E-09 +/- 4.14E-08
# dq = 1.83E-09 +/- 1.43E-08
#
# Iteration 8000/40000
# q = 9.91E-09 +/- 9.63E-08
# dq = 3.96E-09 +/- 4.07E-08
#
# Iteration 8500/40000
# q = 1.10E-08 +/- 8.35E-08
# dq = 4.07E-09 +/- 4.26E-08
#
# Iteration 9000/40000
# q = 7.14E-09 +/- 5.31E-08
# dq = 2.33E-09 +/- 1.85E-08
#
# Iteration 9500/40000
# q = 6.87E-09 +/- 5.54E-08
# dq = 2.71E-09 +/- 1.73E-08
#
# Iteration 10000/40000
# q = 8.11E-09 +/- 5.79E-08
# dq = 2.99E-09 +/- 1.86E-08
#
# Iteration 10500/40000
# q = 6.21E-09 +/- 5.35E-08
# dq = 2.54E-09 +/- 2.17E-08
#
# Iteration 11000/40000
# q = 5.65E-09 +/- 4.94E-08
# dq = 1.73E-09 +/- 1.28E-08
#
# Iteration 11500/40000
# q = 6.63E-09 +/- 4.76E-08
# dq = 2.58E-09 +/- 1.55E-08
#
# Iteration 12000/40000
# q = 6.62E-09 +/- 6.02E-08
# dq = 2.19E-09 +/- 1.46E-08
#
# Iteration 12500/40000
# q = 8.95E-09 +/- 5.87E-08
# dq = 2.89E-09 +/- 1.73E-08
#
# Iteration 13000/40000
# q = 4.86E-09 +/- 3.68E-08
# dq = 4.74E-09 +/- 6.82E-08
#
# Iteration 13500/40000
# q = 6.41E-09 +/- 4.75E-08
# dq = 2.47E-09 +/- 1.90E-08
#
# Iteration 14000/40000
# q = 6.21E-09 +/- 5.41E-08
# dq = 3.68E-09 +/- 4.36E-08
#
# Iteration 14500/40000
# q = 5.29E-09 +/- 3.41E-08
# dq = 2.35E-09 +/- 1.65E-08
#
# Iteration 15000/40000
# q = 8.67E-09 +/- 6.13E-08
# dq = 3.80E-09 +/- 2.94E-08
#
# Iteration 15500/40000
# q = 6.48E-09 +/- 6.19E-08
# dq = 2.25E-09 +/- 1.74E-08
#
# Iteration 16000/40000
# q = 5.67E-09 +/- 4.08E-08
# dq = 1.78E-09 +/- 1.05E-08
#
# Iteration 16500/40000
# q = 1.20E-08 +/- 1.60E-07
# dq = 3.66E-09 +/- 4.12E-08
#
# Iteration 17000/40000
# q = 8.51E-09 +/- 6.40E-08
# dq = 2.74E-09 +/- 1.74E-08
#
# Iteration 17500/40000
# q = 4.70E-09 +/- 2.94E-08
# dq = 4.56E-09 +/- 4.71E-08
#
# Iteration 18000/40000
# q = 6.27E-09 +/- 4.61E-08
# dq = 2.19E-09 +/- 1.35E-08
#
# Iteration 18500/40000
# q = 1.14E-08 +/- 1.67E-07
# dq = 4.93E-09 +/- 8.88E-08
#
# Iteration 19000/40000
# q = 8.18E-09 +/- 6.10E-08
# dq = 2.51E-09 +/- 1.55E-08
#
# Iteration 19500/40000
# q = 5.95E-09 +/- 4.07E-08
# dq = 2.69E-09 +/- 1.98E-08
#
# Iteration 20000/40000
# q = 8.19E-09 +/- 6.47E-08
# dq = 3.71E-09 +/- 4.26E-08
#
# Iteration 20500/40000
# q = 9.17E-09 +/- 6.24E-08
# dq = 3.39E-09 +/- 2.29E-08
#
# Iteration 21000/40000
# q = 7.13E-09 +/- 5.18E-08
# dq = 2.14E-09 +/- 1.67E-08
#
# Iteration 21500/40000
# q = 1.02E-08 +/- 9.95E-08
# dq = 4.11E-09 +/- 3.88E-08
#
# Iteration 22000/40000
# q = 1.01E-08 +/- 1.01E-07
# dq = 3.24E-09 +/- 2.59E-08
#
# Iteration 22500/40000
# q = 6.56E-09 +/- 5.09E-08
# dq = 2.44E-09 +/- 1.60E-08
#
# Iteration 23000/40000
# q = 7.11E-09 +/- 5.46E-08
# dq = 3.53E-09 +/- 2.59E-08
#
# Iteration 23500/40000
# q = 6.51E-09 +/- 4.76E-08
# dq = 2.37E-09 +/- 1.41E-08
#
# Iteration 24000/40000
# q = 7.74E-09 +/- 5.81E-08
# dq = 4.19E-09 +/- 3.42E-08
#
# Iteration 24500/40000
# q = 8.09E-09 +/- 5.14E-08
# dq = 3.90E-09 +/- 2.65E-08
#
# Iteration 25000/40000
# q = 1.18E-08 +/- 1.66E-07
# dq = 5.18E-09 +/- 6.82E-08
#
# Iteration 25500/40000
# q = 4.15E-09 +/- 2.48E-08
# dq = 1.97E-09 +/- 1.32E-08
#
# Iteration 26000/40000
# q = 1.17E-08 +/- 9.73E-08
# dq = 5.65E-09 +/- 7.07E-08
#
# Iteration 26500/40000
# q = 5.12E-09 +/- 4.05E-08
# dq = 1.82E-09 +/- 1.45E-08
#
# Iteration 27000/40000
# q = 1.20E-08 +/- 1.76E-07
# dq = 4.42E-09 +/- 5.82E-08
#
# Iteration 27500/40000
# q = 5.67E-09 +/- 4.18E-08
# dq = 2.45E-09 +/- 1.83E-08
#
# Iteration 28000/40000
# q = 8.27E-09 +/- 5.63E-08
# dq = 2.31E-09 +/- 1.40E-08
#
# Iteration 28500/40000
# q = 6.48E-09 +/- 4.44E-08
# dq = 2.27E-09 +/- 1.52E-08
#
# Iteration 29000/40000
# q = 6.29E-09 +/- 3.65E-08
# dq = 2.21E-09 +/- 1.26E-08
#
# Iteration 29500/40000
# q = 6.00E-09 +/- 4.68E-08
# dq = 2.00E-09 +/- 1.30E-08
#
# Iteration 30000/40000
# q = 6.42E-09 +/- 4.72E-08
# dq = 2.56E-09 +/- 1.85E-08
#
# Iteration 30500/40000
# q = 7.15E-09 +/- 5.94E-08
# dq = 2.54E-09 +/- 1.84E-08
#
# Iteration 31000/40000
# q = 4.58E-09 +/- 3.34E-08
# dq = 1.43E-09 +/- 8.85E-09
#
# Iteration 31500/40000
# q = 9.35E-09 +/- 6.59E-08
# dq = 3.11E-09 +/- 2.04E-08
#
# Iteration 32000/40000
# q = 1.04E-08 +/- 1.12E-07
# dq = 4.69E-09 +/- 7.09E-08
#
# Iteration 32500/40000
# q = 4.42E-09 +/- 3.06E-08
# dq = 1.58E-09 +/- 9.98E-09
#
# Iteration 33000/40000
# q = 7.57E-09 +/- 5.94E-08
# dq = 2.78E-09 +/- 2.04E-08
#
# Iteration 33500/40000
# q = 9.00E-09 +/- 7.37E-08
# dq = 3.75E-09 +/- 3.75E-08
#
# Iteration 34000/40000
# q = 6.17E-09 +/- 4.86E-08
# dq = 2.41E-09 +/- 2.02E-08
#
# Iteration 34500/40000
# q = 1.05E-08 +/- 8.23E-08
# dq = 4.10E-09 +/- 4.45E-08
#
# Iteration 35000/40000
# q = 7.69E-09 +/- 6.13E-08
# dq = 3.22E-09 +/- 3.21E-08
#
# Iteration 35500/40000
# q = 7.69E-09 +/- 6.46E-08
# dq = 3.00E-09 +/- 2.61E-08
#
# Iteration 36000/40000
# q = 7.00E-09 +/- 5.70E-08
# dq = 2.67E-09 +/- 1.82E-08
#
# Iteration 36500/40000
# q = 1.15E-08 +/- 7.58E-08
# dq = 4.04E-09 +/- 2.25E-08
#
# Iteration 37000/40000
# q = 7.19E-09 +/- 5.53E-08
# dq = 3.68E-09 +/- 3.29E-08
#
# Iteration 37500/40000
# q = 1.98E-08 +/- 2.54E-07
# dq = 8.12E-09 +/- 1.09E-07
#
# Iteration 38000/40000
# q = 1.05E-08 +/- 7.14E-08
# dq = 2.77E-09 +/- 1.71E-08
#
# Iteration 38500/40000
# q = 9.28E-09 +/- 7.45E-08
# dq = 4.93E-09 +/- 4.06E-08
#
# Iteration 39000/40000
# q = 8.63E-09 +/- 5.68E-08
# dq = 3.25E-09 +/- 2.56E-08
#
# Iteration 39500/40000
# q = 4.02E-09 +/- 2.83E-08
# dq = 1.80E-09 +/- 1.40E-08
#
# Iteration 40000/40000
# q = 7.37E-09 +/- 4.97E-08
# dq = 2.68E-09 +/- 1.85E-08
# Maximum iteration count reached. Terminating.
# Found 1024 unique fixed points.
# Decomposing Jacobians in a single batch.
# Sorting by Eigenvalue magnitude.

# %%
fpsDT_NODE = analysis_NODE.plot_fps(
    inputs = torch.zeros(3),
    max_iters = 40000,
    learning_rate =5e-3,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fpsDT_NODE = analysis_NODE.plot_fps(
#       2     inputs = torch.zeros(3),
#       3     max_iters = 40000,
#       4     learning_rate =5e-3,
#       5 )
#
# NameError: name 'analysis_NODE' is not defined

# %%
fpsDT_LDS = analysis_LDS.plot_fps(
    inputs = torch.zeros(3),
    max_iters = 40000,
    learning_rate =5e-3,
)
# Out:
# Iteration 500/40000
# q = 8.22E-04 +/- 1.97E-03
# dq = 7.67E-07 +/- 1.58E-05
#
# Iteration 1000/40000
# q = 6.99E-04 +/- 8.57E-04
# dq = 1.47E-07 +/- 2.07E-07
#
# Iteration 1500/40000
# q = 6.18E-04 +/- 7.78E-04
# dq = 1.76E-07 +/- 2.30E-07
#
# Iteration 2000/40000
# q = 5.29E-04 +/- 6.95E-04
# dq = 1.90E-07 +/- 2.41E-07
#
# Iteration 2500/40000
# q = 4.37E-04 +/- 6.12E-04
# dq = 1.95E-07 +/- 2.44E-07
#
# Iteration 3000/40000
# q = 3.48E-04 +/- 5.33E-04
# dq = 1.90E-07 +/- 2.29E-07
#
# Iteration 3500/40000
# q = 2.69E-04 +/- 4.59E-04
# dq = 1.92E-07 +/- 2.74E-07
#
# Iteration 4000/40000
# q = 2.00E-04 +/- 3.91E-04
# dq = 1.76E-07 +/- 3.25E-07
#
# Iteration 4500/40000
# q = 1.45E-04 +/- 3.31E-04
# dq = 1.92E-07 +/- 3.42E-07
#
# Iteration 5000/40000
# q = 1.02E-04 +/- 2.78E-04
# dq = 1.87E-07 +/- 3.57E-07
#
# Iteration 5500/40000
# q = 7.05E-05 +/- 2.31E-04
# dq = 2.14E-07 +/- 4.27E-07
#
# Iteration 6000/40000
# q = 4.79E-05 +/- 1.89E-04
# dq = 2.54E-07 +/- 5.12E-07
#
# Iteration 6500/40000
# q = 3.24E-05 +/- 1.52E-04
# dq = 3.03E-07 +/- 6.61E-07
#
# Iteration 7000/40000
# q = 2.16E-05 +/- 1.19E-04
# dq = 3.00E-07 +/- 6.15E-07
#
# Iteration 7500/40000
# q = 1.43E-05 +/- 8.94E-05
# dq = 3.33E-07 +/- 6.18E-07
#
# Iteration 8000/40000
# q = 9.43E-06 +/- 6.36E-05
# dq = 3.34E-07 +/- 6.32E-07
#
# Iteration 8500/40000
# q = 6.40E-06 +/- 4.19E-05
# dq = 3.62E-07 +/- 6.65E-07
#
# Iteration 9000/40000
# q = 4.30E-06 +/- 2.52E-05
# dq = 3.40E-07 +/- 6.25E-07
#
# Iteration 9500/40000
# q = 2.88E-06 +/- 1.36E-05
# dq = 3.90E-07 +/- 6.88E-07
#
# Iteration 10000/40000
# q = 2.21E-06 +/- 6.86E-06
# dq = 3.62E-07 +/- 6.37E-07
#
# Iteration 10500/40000
# q = 1.91E-06 +/- 3.97E-06
# dq = 3.86E-07 +/- 7.04E-07
#
# Iteration 11000/40000
# q = 1.60E-06 +/- 2.78E-06
# dq = 3.43E-07 +/- 5.86E-07
#
# Iteration 11500/40000
# q = 1.68E-06 +/- 2.84E-06
# dq = 3.89E-07 +/- 7.42E-07
#
# Iteration 12000/40000
# q = 1.43E-06 +/- 2.34E-06
# dq = 3.41E-07 +/- 5.51E-07
#
# Iteration 12500/40000
# q = 1.49E-06 +/- 2.62E-06
# dq = 3.65E-07 +/- 7.06E-07
#
# Iteration 13000/40000
# q = 1.65E-06 +/- 2.99E-06
# dq = 3.78E-07 +/- 7.01E-07
#
# Iteration 13500/40000
# q = 1.66E-06 +/- 2.76E-06
# dq = 3.71E-07 +/- 6.66E-07
#
# Iteration 14000/40000
# q = 1.66E-06 +/- 2.90E-06
# dq = 3.56E-07 +/- 6.11E-07
#
# Iteration 14500/40000
# q = 1.64E-06 +/- 2.71E-06
# dq = 4.06E-07 +/- 7.67E-07
#
# Iteration 15000/40000
# q = 1.57E-06 +/- 2.71E-06
# dq = 3.54E-07 +/- 6.45E-07
#
# Iteration 15500/40000
# q = 1.65E-06 +/- 2.54E-06
# dq = 4.03E-07 +/- 6.57E-07
#
# Iteration 16000/40000
# q = 1.59E-06 +/- 2.71E-06
# dq = 3.75E-07 +/- 6.38E-07
#
# Iteration 16500/40000
# q = 1.56E-06 +/- 2.73E-06
# dq = 3.77E-07 +/- 6.31E-07
#
# Iteration 17000/40000
# q = 1.71E-06 +/- 2.94E-06
# dq = 4.19E-07 +/- 7.64E-07
#
# Iteration 17500/40000
# q = 1.67E-06 +/- 2.85E-06
# dq = 3.70E-07 +/- 6.69E-07
#
# Iteration 18000/40000
# q = 1.58E-06 +/- 2.95E-06
# dq = 3.61E-07 +/- 7.69E-07
#
# Iteration 18500/40000
# q = 1.63E-06 +/- 2.85E-06
# dq = 3.78E-07 +/- 7.11E-07
#
# Iteration 19000/40000
# q = 1.58E-06 +/- 2.79E-06
# dq = 3.59E-07 +/- 6.30E-07
#
# Iteration 19500/40000
# q = 1.67E-06 +/- 2.83E-06
# dq = 3.71E-07 +/- 6.38E-07
#
# Iteration 20000/40000
# q = 1.62E-06 +/- 2.69E-06
# dq = 3.81E-07 +/- 6.98E-07
#
# Iteration 20500/40000
# q = 1.59E-06 +/- 2.74E-06
# dq = 3.60E-07 +/- 6.54E-07
#
# Iteration 21000/40000
# q = 1.61E-06 +/- 2.87E-06
# dq = 3.76E-07 +/- 7.25E-07
#
# Iteration 21500/40000
# q = 1.58E-06 +/- 2.70E-06
# dq = 3.56E-07 +/- 6.50E-07
#
# Iteration 22000/40000
# q = 1.52E-06 +/- 2.67E-06
# dq = 3.31E-07 +/- 6.06E-07
#
# Iteration 22500/40000
# q = 1.75E-06 +/- 2.94E-06
# dq = 4.18E-07 +/- 7.19E-07
#
# Iteration 23000/40000
# q = 1.66E-06 +/- 2.83E-06
# dq = 3.98E-07 +/- 7.60E-07
#
# Iteration 23500/40000
# q = 1.54E-06 +/- 2.69E-06
# dq = 3.75E-07 +/- 6.70E-07
#
# Iteration 24000/40000
# q = 1.58E-06 +/- 2.84E-06
# dq = 3.76E-07 +/- 7.63E-07
#
# Iteration 24500/40000
# q = 1.70E-06 +/- 2.81E-06
# dq = 3.99E-07 +/- 6.79E-07
#
# Iteration 25000/40000
# q = 1.66E-06 +/- 2.83E-06
# dq = 3.98E-07 +/- 6.77E-07
#
# Iteration 25500/40000
# q = 1.57E-06 +/- 2.82E-06
# dq = 3.80E-07 +/- 6.81E-07
#
# Iteration 26000/40000
# q = 1.48E-06 +/- 2.51E-06
# dq = 3.47E-07 +/- 6.26E-07
#
# Iteration 26500/40000
# q = 1.38E-06 +/- 2.43E-06
# dq = 3.27E-07 +/- 5.77E-07
#
# Iteration 27000/40000
# q = 1.47E-06 +/- 2.52E-06
# dq = 3.61E-07 +/- 6.78E-07
#
# Iteration 27500/40000
# q = 1.63E-06 +/- 2.80E-06
# dq = 3.78E-07 +/- 6.68E-07
#
# Iteration 28000/40000
# q = 1.55E-06 +/- 2.67E-06
# dq = 3.75E-07 +/- 6.55E-07
#
# Iteration 28500/40000
# q = 1.51E-06 +/- 2.65E-06
# dq = 3.77E-07 +/- 6.59E-07
#
# Iteration 29000/40000
# q = 1.62E-06 +/- 2.76E-06
# dq = 3.93E-07 +/- 7.25E-07
#
# Iteration 29500/40000
# q = 1.67E-06 +/- 2.78E-06
# dq = 3.96E-07 +/- 6.74E-07
#
# Iteration 30000/40000
# q = 1.56E-06 +/- 2.75E-06
# dq = 3.62E-07 +/- 6.54E-07
#
# Iteration 30500/40000
# q = 1.60E-06 +/- 2.96E-06
# dq = 3.71E-07 +/- 6.43E-07
#
# Iteration 31000/40000
# q = 1.51E-06 +/- 2.61E-06
# dq = 3.59E-07 +/- 6.49E-07
#
# Iteration 31500/40000
# q = 1.47E-06 +/- 2.57E-06
# dq = 3.70E-07 +/- 6.90E-07
#
# Iteration 32000/40000
# q = 1.85E-06 +/- 3.16E-06
# dq = 4.11E-07 +/- 6.85E-07
#
# Iteration 32500/40000
# q = 1.58E-06 +/- 2.66E-06
# dq = 3.80E-07 +/- 7.04E-07
#
# Iteration 33000/40000
# q = 1.63E-06 +/- 2.97E-06
# dq = 4.00E-07 +/- 7.30E-07
#
# Iteration 33500/40000
# q = 1.58E-06 +/- 2.84E-06
# dq = 3.68E-07 +/- 6.76E-07
#
# Iteration 34000/40000
# q = 1.52E-06 +/- 2.59E-06
# dq = 3.22E-07 +/- 6.56E-07
#
# Iteration 34500/40000
# q = 1.52E-06 +/- 2.62E-06
# dq = 3.72E-07 +/- 6.95E-07
#
# Iteration 35000/40000
# q = 1.60E-06 +/- 2.97E-06
# dq = 3.71E-07 +/- 6.54E-07
#
# Iteration 35500/40000
# q = 1.56E-06 +/- 2.70E-06
# dq = 3.75E-07 +/- 6.87E-07
#
# Iteration 36000/40000
# q = 1.62E-06 +/- 2.78E-06
# dq = 3.85E-07 +/- 7.14E-07
#
# Iteration 36500/40000
# q = 1.54E-06 +/- 2.72E-06
# dq = 3.79E-07 +/- 6.58E-07
#
# Iteration 37000/40000
# q = 1.53E-06 +/- 2.71E-06
# dq = 3.74E-07 +/- 6.81E-07
#
# Iteration 37500/40000
# q = 1.59E-06 +/- 2.68E-06
# dq = 3.84E-07 +/- 6.96E-07
#
# Iteration 38000/40000
# q = 1.73E-06 +/- 2.97E-06
# dq = 4.24E-07 +/- 7.74E-07
#
# Iteration 38500/40000
# q = 1.55E-06 +/- 2.59E-06
# dq = 3.91E-07 +/- 7.23E-07
#
# Iteration 39000/40000
# q = 1.65E-06 +/- 2.76E-06
# dq = 4.09E-07 +/- 7.77E-07
#
# Iteration 39500/40000
# q = 1.60E-06 +/- 2.57E-06
# dq = 3.98E-07 +/- 7.02E-07
#
# Iteration 40000/40000
# q = 1.64E-06 +/- 2.80E-06
# dq = 3.86E-07 +/- 7.14E-07
# Maximum iteration count reached. Terminating.
# Found 1024 unique fixed points.
# Decomposing Jacobians in a single batch.
# Sorting by Eigenvalue magnitude.

# %%
lats_TT = an_TT.get_latents().detach().numpy()
lats_GRU = analysis_GRU.get_latents().detach().numpy()
lats_NODE = analysis_NODE.get_latents().detach().numpy()
lats_LDS = analysis_LDS.get_latents().detach().numpy()

plot_model_fps(fpsTT, latents=lats_TT, q_thresh = 1e-7, label = "TT")
plot_model_fps(fpsDT_GRU, latents = lats_GRU, q_thresh = 1e-6, label = "DT_GRU")
plot_model_fps(fpsDT_NODE, latents = lats_NODE, q_thresh = 1e-7, label = "DT_NODE")
plot_model_fps(fpsDT_LDS, latents = lats_LDS, q_thresh = 1e-7, label = "DT_LDS")

# %%
comparison_models = Comparison()
comparison_models.load_analysis(an_TT, reference_analysis=True, group = "TT")
comparison_models.load_analysis(analysis_GRU, group = "GRU")
comparison_models.load_analysis(analysis_NODE, group = "NODE")
comparison_models.load_analysis(analysis_LDS, group = "LDS")
comparison_models.regroup()

# %%
comparison_models.plot_trials_reference(num_trials=2, num_pcs=4)

# %%
lds_fps = analysis_LDS.plot_fps(
    inputs = torch.zeros(3),
    learning_rate = 1e-3,
    n_inits=1024,
    max_iters = 20000,                      
)

# %%
node_fps = analysis_NODE.plot_fps(
    inputs = torch.zeros(3),
    learning_rate = 6e-4,
    n_inits=1024,
    max_iters = 50000,                      
)

# %%
gru_fps = analysis_GRU.plot_fps(
    inputs = torch.zeros(3),
    learning_rate = 6e-4,
    n_inits=1024,
    max_iters = 50000,                      
)

# %%
plot_model_fps(lds_fps, q_thresh = 1e-4)
plot_model_fps(node_fps, q_thresh = 1e-4)
plot_model_fps(gru_fps, q_thresh = 4e-7)
