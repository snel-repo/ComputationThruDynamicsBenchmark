# %%
import matplotlib.pyplot as plt

import numpy as np
import os
from ctd.comparison.analysis.tt.tt import Analysis_TT 
from ctd.comparison.analysis.dt.dt import Analysis_DT
# Import pca
import dotenv
from ctd.comparison.comparison import Comparison

dotenv.load_dotenv(dotenv.find_dotenv())
# Out:
# True

# %%
HOME_DIR = os.environ['HOME_DIR']
print(HOME_DIR)

pathTT = HOME_DIR + 'content/trained_models/task-trained/20240328_NBFF_GRU_Final/n=3 max_epochs=1500 seed=0/'
an_TT = Analysis_TT(run_name = "TT", filepath = pathTT)

path_NODE_Sweep = pathTT + "20240410_NBFF_NODE_DT_LatentSweep_new/"
subfolders_NODE = [f.path for f in os.scandir(path_NODE_Sweep) if f.is_dir()]
# Out:
# /home/csverst/Github/CtDBenchmark/

# %%
print(len(subfolders_NODE))
# Out:
# 16

# %%
comparison = Comparison(comparison_tag="Figure2")
comparison.load_analysis(an_TT, reference_analysis=True, group = "TT")
for subfolder in subfolders_NODE:
    latent_size = int(subfolder.split(" ")[-1].split("=")[-1])
    print(latent_size)
    subfolder = subfolder + "/"
    analysis_temp = Analysis_DT(run_name = f"NODE_{latent_size}", filepath = subfolder, model_type = "SAE")
    comparison.load_analysis(analysis_temp, group = f"NODE_{latent_size}")

comparison.regroup()
print(comparison.groups)
# Out:
# 10
# 8
# 5
# 3
# 8
# 8
# 8
# 3
# 10
# 10
# 5
# 3
# 3
# 5
# 5
# 10
# ['NODE_10' 'NODE_10' 'NODE_10' 'NODE_10' 'NODE_3' 'NODE_3' 'NODE_3'
#  'NODE_3' 'NODE_5' 'NODE_5' 'NODE_5' 'NODE_5' 'NODE_8' 'NODE_8' 'NODE_8'
#  'NODE_8' 'TT']

# %%
comparison.compare_state_rate_r2()
# Out:
# Working on 1 of 17
# Working on 2 of 17
# Working on 3 of 17
# Working on 4 of 17
# Working on 5 of 17
# Working on 6 of 17
# Working on 7 of 17
# Working on 8 of 17
# Working on 9 of 17
# Working on 10 of 17
# Working on 11 of 17
# Working on 12 of 17
# Working on 13 of 17
# Working on 14 of 17
# Working on 15 of 17
# Working on 16 of 17
# Working on 17 of 17
# array([[0.82587396, 0.8839172 ],
#        [0.84098066, 0.89538248],
#        [0.82897991, 0.88948528],
#        [0.83585209, 0.89026186],
#        [0.68915817, 0.81378971],
#        [0.69286842, 0.81887495],
#        [0.69700294, 0.82176624],
#        [0.69506468, 0.81946849],
#        [0.75720526, 0.84682296],
#        [0.76767066, 0.85728119],
#        [0.7664016 , 0.85633495],
#        [0.76460209, 0.85461377],
#        [0.81862043, 0.88106125],
#        [0.82440343, 0.88992361],
#        [0.81798635, 0.88574554],
#        [0.82592146, 0.88923694],
#        [0.        , 0.        ]])

# %%
sims = comparison.compare_dynamics_DSA()
# Out:
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# Computing Hankel matrix ...
# Hankel matrix computed!
# Computing SVD on Hankel matrix ...
# SVD complete!
# Computing least squares fits to HAVOK DMD ...
# Least squares complete!
#
# computing similarity between DMDs 1 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 2 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 2 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 3 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 3 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 3 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 4 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 4 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 4 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 4 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 5 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 5 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 5 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 5 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 5 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 6 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 6 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 6 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 6 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 6 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 6 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 7 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 7 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 7 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 7 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 7 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 7 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 7 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 8 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 8 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 8 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 8 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 8 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 8 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 8 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 8 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 9 and 8
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 8
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 10 and 9
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 8
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 9
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 11 and 10
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 8
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 9
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 10
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 12 and 11
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 8
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 9
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 10
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 11
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 13 and 12
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 8
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 9
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 10
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 11
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 12
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 14 and 13
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 8
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 9
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 10
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 11
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 12
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 13
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 15 and 14
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 0
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 1
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 2
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 3
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 4
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 5
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 6
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 7
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 8
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 9
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 10
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 11
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 12
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 13
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 14
# Finished optimizing C
# Finished optimizing C
# computing similarity between DMDs 16 and 15
# Finished optimizing C
# Finished optimizing C

# %%
# Take upper triangle of sims
sims = np.triu(sims, k=0)
sims = sims.flatten()
self_sim = sims[0]
sims = sims[1:]
fig = plt.figure()
plt.bar(range(len(sims)), sims)
plt.title("Dynamical Similarity")
plt.xlabel("Model")
plt.ylabel("Similarity")
plt.xticks(range(len(sims)), ["GRU", "Vanilla", "NODE"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 11
#       9 plt.xlabel("Model")
#      10 plt.ylabel("Similarity")
# ---> 11 plt.xticks(range(len(sims)), ["GRU", "Vanilla", "NODE"])
#
# File ~/miniconda3/envs/build5/lib/python3.10/site-packages/matplotlib/pyplot.py:2053, in xticks(ticks, labels, minor, **kwargs)
#    2051         l._internal_update(kwargs)
#    2052 else:
# -> 2053     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    2055 return locs, labels_out
#
# File ~/miniconda3/envs/build5/lib/python3.10/site-packages/matplotlib/axes/_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~/miniconda3/envs/build5/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/build5/lib/python3.10/site-packages/matplotlib/axis.py:2025, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2021 elif isinstance(locator, mticker.FixedLocator):
#    2022     # Passing [] as a list of labels is often used as a way to
#    2023     # remove all tick labels, so only error for > 0 labels
#    2024     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2025         raise ValueError(
#    2026             "The number of FixedLocator locations"
#    2027             f" ({len(locator.locs)}), usually from a call to"
#    2028             " set_ticks, does not match"
#    2029             f" the number of labels ({len(labels)}).")
#    2030     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2031     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (288), usually from a call to set_ticks, does not match the number of labels (3).

# %% [markdown]
# comparison.compare_to_reference_affine
