# %%
import matplotlib.pyplot as plt

import numpy as np
import os
from ctd.comparison.analysis.tt.tt import Analysis_TT 
from ctd.comparison.analysis.dt.dt import Analysis_DT
# Import pca
import dotenv
from ctd.comparison.comparison import Comparison
import torch
from sklearn.decomposition import PCA

dotenv.load_dotenv(dotenv.find_dotenv())
# Out:
# True

# %%
HOME_DIR = os.environ['HOME_DIR']
print(HOME_DIR)

pathTT = HOME_DIR + 'content/trained_models/task-trained/20240503_Fig1_NBFF_NODE/max_epochs=500 n_samples=1000 latent_size=3 seed=0 learning_rate=0.001/'
an_TT = Analysis_TT(run_name = "TT", filepath = pathTT)


path_GRU_Sweep = pathTT + "20240508_Fig3_NBFF_GRU_TT_NODE_LatSweep/"
subfolders_GRU = [f.path for f in os.scandir(path_GRU_Sweep) if f.is_dir()]

path_GRU128 = pathTT + "20240506_Fig1_NBFF_GRU_TT_NODE_Sweep/"
subfolders_GRU128 = [f.path for f in os.scandir(path_GRU128) if f.is_dir() and "latent_size=128" in f.path]
# Out:
# /home/csverst/Github/CtDBenchmark/

# %%
comparison = Comparison(comparison_tag="Figure1NBFF_TTGRU_Sweep")
comparison.load_analysis(an_TT, reference_analysis=True, group = "TT")

for subfolder in subfolders_GRU:
    
    final_folder = subfolder.split("/")[-1]
    subfolder = subfolder + "/"
    print(final_folder)
    # Find the latent size in the folder name
    latent_size = int(final_folder.split("latent_size=")[1].split(" ")[0])

    analysis_GRU = Analysis_DT(run_name = f"GRU_{latent_size}", filepath = subfolder, model_type = "SAE")
    comparison.load_analysis(analysis_GRU, group = f"GRU_{latent_size}")

comparison.regroup()
# Out:
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=3 max_epochs=1000 latent_size=5
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=2 max_epochs=1000 latent_size=3
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=0 max_epochs=1000 latent_size=5
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=1 max_epochs=1000 latent_size=10
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=3 max_epochs=1000 latent_size=8
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=2 max_epochs=1000 latent_size=5
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=3 max_epochs=1000 latent_size=10
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=1 max_epochs=1000 latent_size=3
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=1 max_epochs=1000 latent_size=8
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=3 max_epochs=1000 latent_size=3
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=2 max_epochs=1000 latent_size=8
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=0 max_epochs=1000 latent_size=10
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=1 max_epochs=1000 latent_size=5
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=2 max_epochs=1000 latent_size=10
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=0 max_epochs=1000 latent_size=8
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=0 max_epochs=1000 latent_size=3
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=4 max_epochs=1000 latent_size=3
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=4 max_epochs=1000 latent_size=8
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=4 max_epochs=1000 latent_size=5
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=4 max_epochs=1000 latent_size=10
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=0 max_epochs=1000 latent_size=16
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=0 max_epochs=1000 latent_size=64
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=0 max_epochs=1000 latent_size=128
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=1 max_epochs=1000 latent_size=16
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=1 max_epochs=1000 latent_size=64
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=2 max_epochs=1000 latent_size=16
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=2 max_epochs=1000 latent_size=64
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=2 max_epochs=1000 latent_size=128
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=3 max_epochs=1000 latent_size=16
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=3 max_epochs=1000 latent_size=64
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=3 max_epochs=1000 latent_size=128
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=4 max_epochs=1000 latent_size=16
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=4 max_epochs=1000 latent_size=64
# gen_model=NODE prefix=20240503_Fig1_NBFF_NODE seed=4 max_epochs=1000 latent_size=128

# %%
plot_dict = {
    "save_pdf": True,
    "ax_lim": [0.15, 1.05],
    "marker": "x",
}
comparison.compare_rate_state_r2(plot_dict=plot_dict)
# Out:
# Working on 1 of 35: GRU_10
# Group: GRU_10
# Rate R2: 0.9874105024240137
# State R2: 0.9506817956157428
# Working on 2 of 35: GRU_10
# Group: GRU_10
# Rate R2: 0.9861462555663439
# State R2: 0.9440069507894451
# Working on 3 of 35: GRU_10
# Group: GRU_10
# Rate R2: 0.9858411822367986
# State R2: 0.9207000182953031
# Working on 4 of 35: GRU_10
# Group: GRU_10
# Rate R2: 0.9856333135770755
# State R2: 0.9415490912899641
# Working on 5 of 35: GRU_10
# Group: GRU_10
# Rate R2: 0.9866689519237007
# State R2: 0.9477715178772907
# Working on 6 of 35: GRU_128
# Group: GRU_128
# Rate R2: 0.9674133165958994
# State R2: 0.6561357592518599
# Working on 7 of 35: GRU_128
# Group: GRU_128
# Rate R2: 0.9629997394540196
# State R2: 0.6489522874009994
# Working on 8 of 35: GRU_128
# Group: GRU_128
# Rate R2: 0.9673058396547058
# State R2: 0.646267851253092
# Working on 9 of 35: GRU_128
# Group: GRU_128
# Rate R2: 0.9657957689946902
# State R2: 0.670112508629373
# Working on 10 of 35: GRU_16
# Group: GRU_16
# Rate R2: 0.9875483255765929
# State R2: 0.9240337036082062
# Working on 11 of 35: GRU_16
# Group: GRU_16
# Rate R2: 0.9887216195899902
# State R2: 0.9250099768251984
# Working on 12 of 35: GRU_16
# Group: GRU_16
# Rate R2: 0.9877676260005623
# State R2: 0.9194012813416306
# Working on 13 of 35: GRU_16
# Group: GRU_16
# Rate R2: 0.9869002433257796
# State R2: 0.9245444459417991
# Working on 14 of 35: GRU_16
# Group: GRU_16
# Rate R2: 0.9897281820094349
# State R2: 0.9328207872651622
# Working on 15 of 35: GRU_3
# Group: GRU_3
# Rate R2: 0.52230496341543
# State R2: 0.762423057037739
# Working on 16 of 35: GRU_3
# Group: GRU_3
# Rate R2: 0.4930896302946824
# State R2: 0.7129237002831533
# Working on 17 of 35: GRU_3
# Group: GRU_3
# Rate R2: 0.5145001581461378
# State R2: 0.735405570460804
# Working on 18 of 35: GRU_3
# Group: GRU_3
# Rate R2: 0.5140793097228177
# State R2: 0.7851213081368887
# Working on 19 of 35: GRU_3
# Group: GRU_3
# Rate R2: 0.4360498697667314
# State R2: 0.6252322966203688
# Working on 20 of 35: GRU_5
# Group: GRU_5
# Rate R2: 0.8766886576282729
# State R2: 0.8497695611683954
# Working on 21 of 35: GRU_5
# Group: GRU_5
# Rate R2: 0.8541666515556944
# State R2: 0.8433467315872896
# Working on 22 of 35: GRU_5
# Group: GRU_5
# Rate R2: 0.8579317771213978
# State R2: 0.8466956070053803
# Working on 23 of 35: GRU_5
# Group: GRU_5
# Rate R2: 0.9432092722609039
# State R2: 0.9212419535995021
# Working on 24 of 35: GRU_5
# Group: GRU_5
# Rate R2: 0.8014249719918296
# State R2: 0.8624158798257092
# Working on 25 of 35: GRU_64
# Group: GRU_64
# Rate R2: 0.9841483842782442
# State R2: 0.8063471737608706
# Working on 26 of 35: GRU_64
# Group: GRU_64
# Rate R2: 0.9876922627778021
# State R2: 0.8010797338322537
# Working on 27 of 35: GRU_64
# Group: GRU_64
# Rate R2: 0.9873030686995092
# State R2: 0.7934537685904797
# Working on 28 of 35: GRU_64
# Group: GRU_64
# Rate R2: 0.9872621760086173
# State R2: 0.8081115823692355
# Working on 29 of 35: GRU_64
# Group: GRU_64
# Rate R2: 0.985241626160669
# State R2: 0.8125190988440743
# Working on 30 of 35: GRU_8
# Group: GRU_8
# Rate R2: 0.9831798831328862
# State R2: 0.9512983988995319
# Working on 31 of 35: GRU_8
# Group: GRU_8
# Rate R2: 0.9826657486765796
# State R2: 0.9382005797186928
# Working on 32 of 35: GRU_8
# Group: GRU_8
# Rate R2: 0.9865012112596913
# State R2: 0.9291585854557705
# Working on 33 of 35: GRU_8
# Group: GRU_8
# Rate R2: 0.9812319569047457
# State R2: 0.9348295130296292
# Working on 34 of 35: GRU_8
# Group: GRU_8
# Rate R2: 0.9849571033690913
# State R2: 0.9425162718645489
# Working on 35 of 35: TT
# Group: TT
# array([[0.9874105 , 0.9506818 ],
#        [0.98614626, 0.94400695],
#        [0.98584118, 0.92070002],
#        [0.98563331, 0.94154909],
#        [0.98666895, 0.94777152],
#        [0.96741332, 0.65613576],
#        [0.96299974, 0.64895229],
#        [0.96730584, 0.64626785],
#        [0.96579577, 0.67011251],
#        [0.98754833, 0.9240337 ],
#        [0.98872162, 0.92500998],
#        [0.98776763, 0.91940128],
#        [0.98690024, 0.92454445],
#        [0.98972818, 0.93282079],
#        [0.52230496, 0.76242306],
#        [0.49308963, 0.7129237 ],
#        [0.51450016, 0.73540557],
#        [0.51407931, 0.78512131],
#        [0.43604987, 0.6252323 ],
#        [0.87668866, 0.84976956],
#        [0.85416665, 0.84334673],
#        [0.85793178, 0.84669561],
#        [0.94320927, 0.92124195],
#        [0.80142497, 0.86241588],
#        [0.98414838, 0.80634717],
#        [0.98769226, 0.80107973],
#        [0.98730307, 0.79345377],
#        [0.98726218, 0.80811158],
#        [0.98524163, 0.8125191 ],
#        [0.98317988, 0.9512984 ],
#        [0.98266575, 0.93820058],
#        [0.98650121, 0.92915859],
#        [0.98123196, 0.93482951],
#        [0.9849571 , 0.94251627],
#        [0.        , 0.        ]])

# %%
fpsTT = an_TT.plot_fps(
    inputs = torch.zeros(3),
    max_iters = 40000,
    learning_rate =5e-3,
)
# Out:
# Iteration 500/40000
# q = 3.48E-07 +/- 7.52E-06
# dq = 1.72E-10 +/- 5.46E-09
#
# Iteration 1000/40000
# q = 3.31E-07 +/- 7.50E-06
# dq = 7.22E-13 +/- 1.62E-11
#
# Iteration 1500/40000
# q = 1.14E-07 +/- 3.65E-06
# dq = 5.44E-09 +/- 1.74E-07
#
# Iteration 2000/40000
# q = 1.95E-15 +/- 3.69E-14
# dq = 2.82E-16 +/- 4.85E-15
#
# Iteration 2500/40000
# q = 5.89E-13 +/- 1.86E-11
# dq = 1.39E-13 +/- 4.37E-12
#
# Iteration 3000/40000
# q = 7.20E-13 +/- 2.25E-11
# dq = 7.12E-13 +/- 2.21E-11
#
# Iteration 3500/40000
# q = 1.66E-11 +/- 2.45E-10
# dq = 5.09E-12 +/- 7.90E-11
#
# Iteration 4000/40000
# q = 7.33E-12 +/- 1.97E-10
# dq = 1.33E-12 +/- 3.35E-11
#
# Iteration 4500/40000
# q = 4.62E-12 +/- 1.02E-10
# dq = 2.39E-12 +/- 5.02E-11
#
# Iteration 5000/40000
# q = 5.41E-11 +/- 1.16E-09
# dq = 1.32E-11 +/- 2.77E-10
#
# Iteration 5500/40000
# q = 8.12E-12 +/- 2.19E-10
# dq = 2.81E-12 +/- 6.06E-11
#
# Iteration 6000/40000
# q = 2.73E-11 +/- 5.34E-10
# dq = 8.31E-12 +/- 1.48E-10
#
# Iteration 6500/40000
# q = 1.52E-10 +/- 2.54E-09
# dq = 6.78E-11 +/- 1.01E-09
#
# Iteration 7000/40000
# q = 2.28E-10 +/- 3.20E-09
# dq = 5.30E-11 +/- 6.77E-10
#
# Iteration 7500/40000
# q = 7.90E-11 +/- 1.32E-09
# dq = 2.54E-11 +/- 3.33E-10
#
# Iteration 8000/40000
# q = 1.27E-10 +/- 1.88E-09
# dq = 2.96E-11 +/- 3.17E-10
#
# Iteration 8500/40000
# q = 9.09E-11 +/- 1.48E-09
# dq = 2.75E-11 +/- 3.84E-10
#
# Iteration 9000/40000
# q = 1.19E-10 +/- 1.37E-09
# dq = 6.65E-11 +/- 7.72E-10
#
# Iteration 9500/40000
# q = 1.07E-10 +/- 1.65E-09
# dq = 3.15E-11 +/- 3.05E-10
#
# Iteration 10000/40000
# q = 2.00E-10 +/- 3.21E-09
# dq = 5.49E-11 +/- 8.04E-10
#
# Iteration 10500/40000
# q = 1.02E-10 +/- 1.45E-09
# dq = 3.90E-11 +/- 4.77E-10
#
# Iteration 11000/40000
# q = 1.56E-10 +/- 1.73E-09
# dq = 5.27E-11 +/- 5.93E-10
#
# Iteration 11500/40000
# q = 1.23E-10 +/- 1.70E-09
# dq = 5.55E-11 +/- 6.92E-10
#
# Iteration 12000/40000
# q = 1.06E-10 +/- 1.48E-09
# dq = 3.42E-11 +/- 3.44E-10
#
# Iteration 12500/40000
# q = 7.56E-11 +/- 9.33E-10
# dq = 4.25E-11 +/- 6.37E-10
#
# Iteration 13000/40000
# q = 5.00E-11 +/- 5.74E-10
# dq = 2.53E-11 +/- 3.47E-10
#
# Iteration 13500/40000
# q = 1.49E-10 +/- 2.23E-09
# dq = 5.40E-11 +/- 5.97E-10
#
# Iteration 14000/40000
# q = 1.51E-10 +/- 1.73E-09
# dq = 5.80E-11 +/- 6.12E-10
#
# Iteration 14500/40000
# q = 1.44E-10 +/- 2.26E-09
# dq = 3.27E-11 +/- 4.90E-10
#
# Iteration 15000/40000
# q = 9.93E-11 +/- 1.40E-09
# dq = 4.05E-11 +/- 4.88E-10
#
# Iteration 15500/40000
# q = 1.61E-10 +/- 2.18E-09
# dq = 3.71E-11 +/- 4.48E-10
#
# Iteration 16000/40000
# q = 9.88E-11 +/- 1.29E-09
# dq = 1.73E-11 +/- 2.03E-10
#
# Iteration 16500/40000
# q = 5.57E-11 +/- 1.17E-09
# dq = 3.52E-11 +/- 5.12E-10
#
# Iteration 17000/40000
# q = 4.08E-11 +/- 4.04E-10
# dq = 2.60E-11 +/- 2.55E-10
#
# Iteration 17500/40000
# q = 8.43E-11 +/- 1.46E-09
# dq = 3.85E-11 +/- 4.36E-10
#
# Iteration 18000/40000
# q = 8.19E-11 +/- 9.52E-10
# dq = 4.24E-11 +/- 6.71E-10
#
# Iteration 18500/40000
# q = 4.70E-11 +/- 6.21E-10
# dq = 2.35E-11 +/- 3.30E-10
#
# Iteration 19000/40000
# q = 1.94E-10 +/- 2.26E-09
# dq = 7.21E-11 +/- 7.47E-10
#
# Iteration 19500/40000
# q = 1.21E-10 +/- 1.89E-09
# dq = 2.85E-11 +/- 3.12E-10
#
# Iteration 20000/40000
# q = 1.00E-10 +/- 1.75E-09
# dq = 1.79E-11 +/- 2.21E-10
#
# Iteration 20500/40000
# q = 1.63E-10 +/- 1.75E-09
# dq = 5.55E-11 +/- 6.85E-10
#
# Iteration 21000/40000
# q = 1.59E-10 +/- 2.02E-09
# dq = 6.08E-11 +/- 5.76E-10
#
# Iteration 21500/40000
# q = 7.23E-11 +/- 9.26E-10
# dq = 2.64E-11 +/- 3.83E-10
#
# Iteration 22000/40000
# q = 1.42E-10 +/- 1.58E-09
# dq = 6.03E-11 +/- 7.46E-10
#
# Iteration 22500/40000
# q = 1.71E-10 +/- 2.53E-09
# dq = 5.33E-11 +/- 6.71E-10
#
# Iteration 23000/40000
# q = 2.85E-10 +/- 3.30E-09
# dq = 6.42E-11 +/- 6.64E-10
#
# Iteration 23500/40000
# q = 3.34E-11 +/- 4.87E-10
# dq = 1.60E-11 +/- 2.71E-10
#
# Iteration 24000/40000
# q = 9.92E-11 +/- 1.31E-09
# dq = 4.15E-11 +/- 6.72E-10
#
# Iteration 24500/40000
# q = 1.50E-10 +/- 2.09E-09
# dq = 5.16E-11 +/- 6.21E-10
#
# Iteration 25000/40000
# q = 1.13E-10 +/- 1.49E-09
# dq = 2.90E-11 +/- 3.37E-10
#
# Iteration 25500/40000
# q = 5.15E-11 +/- 6.58E-10
# dq = 1.62E-11 +/- 2.02E-10
#
# Iteration 26000/40000
# q = 1.14E-10 +/- 1.28E-09
# dq = 4.58E-11 +/- 5.89E-10
#
# Iteration 26500/40000
# q = 1.70E-10 +/- 2.53E-09
# dq = 4.52E-11 +/- 5.57E-10
#
# Iteration 27000/40000
# q = 1.89E-10 +/- 2.75E-09
# dq = 5.38E-11 +/- 6.53E-10

# %%
fpsDT_GRU = analysis_GRU.plot_fps(
    inputs = torch.zeros(3),
    max_iters = 40000,
    learning_rate =5e-3,
)
# Out:
# Iteration 500/40000
# q = 8.22E-05 +/- 1.27E-03
# dq = 4.05E-07 +/- 6.34E-06
#
# Iteration 1000/40000
# q = 1.15E-05 +/- 1.65E-04
# dq = 3.96E-08 +/- 6.12E-07
#
# Iteration 1500/40000
# q = 2.89E-06 +/- 3.00E-05
# dq = 9.16E-09 +/- 9.09E-08
#
# Iteration 2000/40000
# q = 1.58E-06 +/- 1.32E-05
# dq = 3.44E-09 +/- 1.70E-08
#
# Iteration 2500/40000
# q = 1.11E-06 +/- 8.90E-06
# dq = 3.62E-09 +/- 2.22E-08
#
# Iteration 3000/40000
# q = 7.93E-07 +/- 5.89E-06
# dq = 4.03E-09 +/- 3.20E-08
#
# Iteration 3500/40000
# q = 5.78E-07 +/- 3.86E-06
# dq = 3.78E-09 +/- 4.37E-08
#
# Iteration 4000/40000
# q = 4.36E-07 +/- 2.60E-06
# dq = 5.05E-09 +/- 6.30E-08
#
# Iteration 4500/40000
# q = 3.37E-07 +/- 1.89E-06
# dq = 5.03E-09 +/- 5.67E-08
#
# Iteration 5000/40000
# q = 2.70E-07 +/- 1.49E-06
# dq = 3.48E-09 +/- 3.25E-08
#
# Iteration 5500/40000
# q = 2.25E-07 +/- 1.23E-06
# dq = 4.12E-09 +/- 4.20E-08
#
# Iteration 6000/40000
# q = 1.87E-07 +/- 1.01E-06
# dq = 3.29E-09 +/- 3.67E-08
#
# Iteration 6500/40000
# q = 1.57E-07 +/- 8.32E-07
# dq = 2.94E-09 +/- 3.08E-08
#
# Iteration 7000/40000
# q = 1.33E-07 +/- 7.13E-07
# dq = 3.56E-09 +/- 5.39E-08
#
# Iteration 7500/40000
# q = 1.21E-07 +/- 6.38E-07
# dq = 5.63E-09 +/- 1.02E-07
#
# Iteration 8000/40000
# q = 1.02E-07 +/- 5.39E-07
# dq = 2.72E-09 +/- 1.84E-08
#
# Iteration 8500/40000
# q = 8.77E-08 +/- 4.52E-07
# dq = 2.64E-09 +/- 1.55E-08
#
# Iteration 9000/40000
# q = 7.70E-08 +/- 3.67E-07
# dq = 5.58E-09 +/- 6.99E-08
#
# Iteration 9500/40000
# q = 6.49E-08 +/- 2.74E-07
# dq = 3.27E-09 +/- 3.52E-08
#
# Iteration 10000/40000
# q = 5.43E-08 +/- 1.98E-07
# dq = 1.50E-09 +/- 9.05E-09
#
# Iteration 10500/40000
# q = 4.80E-08 +/- 1.41E-07
# dq = 1.59E-09 +/- 7.59E-09
#
# Iteration 11000/40000
# q = 4.42E-08 +/- 1.11E-07
# dq = 2.21E-09 +/- 2.73E-08
#
# Iteration 11500/40000
# q = 4.20E-08 +/- 1.01E-07
# dq = 2.96E-09 +/- 3.62E-08
#
# Iteration 12000/40000
# q = 3.71E-08 +/- 5.97E-08
# dq = 1.76E-09 +/- 7.03E-09
#
# Iteration 12500/40000
# q = 3.48E-08 +/- 5.33E-08
# dq = 2.06E-09 +/- 1.63E-08
#
# Iteration 13000/40000
# q = 3.38E-08 +/- 5.43E-08
# dq = 1.77E-09 +/- 8.28E-09
#
# Iteration 13500/40000
# q = 3.14E-08 +/- 4.48E-08
# dq = 1.84E-09 +/- 8.89E-09
#
# Iteration 14000/40000
# q = 3.16E-08 +/- 5.34E-08
# dq = 3.55E-09 +/- 3.03E-08
#
# Iteration 14500/40000
# q = 2.99E-08 +/- 5.97E-08
# dq = 2.53E-09 +/- 2.77E-08
#
# Iteration 15000/40000
# q = 2.73E-08 +/- 3.84E-08
# dq = 1.42E-09 +/- 5.28E-09
#
# Iteration 15500/40000
# q = 2.85E-08 +/- 6.37E-08
# dq = 2.98E-09 +/- 5.11E-08
#
# Iteration 16000/40000
# q = 2.52E-08 +/- 3.50E-08
# dq = 1.67E-09 +/- 9.03E-09
#
# Iteration 16500/40000
# q = 2.46E-08 +/- 3.49E-08
# dq = 2.56E-09 +/- 3.39E-08
#
# Iteration 17000/40000
# q = 2.74E-08 +/- 5.51E-08
# dq = 4.19E-09 +/- 4.31E-08
#
# Iteration 17500/40000
# q = 2.33E-08 +/- 3.33E-08
# dq = 2.40E-09 +/- 3.14E-08
#
# Iteration 18000/40000
# q = 2.33E-08 +/- 3.38E-08
# dq = 1.63E-09 +/- 9.26E-09
#
# Iteration 18500/40000
# q = 2.24E-08 +/- 3.63E-08
# dq = 2.51E-09 +/- 2.69E-08
#
# Iteration 19000/40000
# q = 2.17E-08 +/- 3.16E-08
# dq = 1.74E-09 +/- 7.37E-09
#
# Iteration 19500/40000
# q = 2.11E-08 +/- 3.23E-08
# dq = 1.39E-09 +/- 6.44E-09
#
# Iteration 20000/40000
# q = 2.15E-08 +/- 3.70E-08
# dq = 1.67E-09 +/- 1.39E-08
#
# Iteration 20500/40000
# q = 1.95E-08 +/- 2.87E-08
# dq = 1.47E-09 +/- 7.60E-09
#
# Iteration 21000/40000
# q = 2.08E-08 +/- 3.31E-08
# dq = 2.51E-09 +/- 2.18E-08
#
# Iteration 21500/40000
# q = 1.99E-08 +/- 3.14E-08
# dq = 1.53E-09 +/- 5.69E-09
#
# Iteration 22000/40000
# q = 1.88E-08 +/- 2.83E-08
# dq = 1.62E-09 +/- 8.41E-09
#
# Iteration 22500/40000
# q = 1.81E-08 +/- 2.77E-08
# dq = 1.24E-09 +/- 5.11E-09
#
# Iteration 23000/40000
# q = 1.95E-08 +/- 3.12E-08
# dq = 1.94E-09 +/- 8.21E-09
#
# Iteration 23500/40000
# q = 1.77E-08 +/- 2.61E-08
# dq = 1.21E-09 +/- 4.50E-09
#
# Iteration 24000/40000
# q = 1.63E-08 +/- 2.45E-08
# dq = 1.14E-09 +/- 5.15E-09
#
# Iteration 24500/40000
# q = 1.88E-08 +/- 3.03E-08
# dq = 2.05E-09 +/- 7.96E-09
#
# Iteration 25000/40000
# q = 1.75E-08 +/- 2.82E-08
# dq = 1.49E-09 +/- 5.99E-09
#
# Iteration 25500/40000
# q = 1.84E-08 +/- 3.33E-08
# dq = 2.37E-09 +/- 1.68E-08
#
# Iteration 26000/40000
# q = 1.66E-08 +/- 2.60E-08
# dq = 1.55E-09 +/- 6.06E-09
#
# Iteration 26500/40000
# q = 1.59E-08 +/- 2.56E-08
# dq = 1.37E-09 +/- 6.93E-09
#
# Iteration 27000/40000
# q = 1.59E-08 +/- 2.55E-08
# dq = 1.68E-09 +/- 7.98E-09
#
# Iteration 27500/40000
# q = 1.64E-08 +/- 2.79E-08
# dq = 1.53E-09 +/- 6.50E-09
#
# Iteration 28000/40000
# q = 1.63E-08 +/- 3.11E-08
# dq = 2.25E-09 +/- 1.16E-08
#
# Iteration 28500/40000
# q = 1.45E-08 +/- 2.24E-08
# dq = 1.34E-09 +/- 6.38E-09
#
# Iteration 29000/40000
# q = 1.68E-08 +/- 7.15E-08
# dq = 2.81E-09 +/- 3.70E-08
#
# Iteration 29500/40000
# q = 1.54E-08 +/- 2.55E-08
# dq = 2.06E-09 +/- 9.91E-09
#
# Iteration 30000/40000
# q = 1.42E-08 +/- 2.36E-08
# dq = 1.26E-09 +/- 5.07E-09
#
# Iteration 30500/40000
# q = 1.56E-08 +/- 3.33E-08
# dq = 1.56E-09 +/- 6.13E-09
#
# Iteration 31000/40000
# q = 1.33E-08 +/- 2.14E-08
# dq = 1.10E-09 +/- 4.75E-09
#
# Iteration 31500/40000
# q = 1.44E-08 +/- 2.57E-08
# dq = 1.61E-09 +/- 7.25E-09
#
# Iteration 32000/40000
# q = 1.36E-08 +/- 2.34E-08
# dq = 1.47E-09 +/- 6.83E-09
#
# Iteration 32500/40000
# q = 1.43E-08 +/- 2.98E-08
# dq = 3.87E-09 +/- 6.55E-08
#
# Iteration 33000/40000
# q = 1.39E-08 +/- 2.48E-08
# dq = 1.51E-09 +/- 6.18E-09
#
# Iteration 33500/40000
# q = 1.30E-08 +/- 2.25E-08
# dq = 1.14E-09 +/- 4.74E-09
#
# Iteration 34000/40000
# q = 1.99E-08 +/- 1.63E-07
# dq = 2.51E-09 +/- 2.15E-08
#
# Iteration 34500/40000
# q = 1.22E-08 +/- 2.10E-08
# dq = 1.19E-09 +/- 5.67E-09
#
# Iteration 35000/40000
# q = 1.70E-08 +/- 1.44E-07
# dq = 4.61E-09 +/- 1.02E-07
#
# Iteration 35500/40000
# q = 1.23E-08 +/- 2.10E-08
# dq = 1.46E-09 +/- 5.61E-09
#
# Iteration 36000/40000
# q = 1.26E-08 +/- 2.24E-08
# dq = 2.49E-09 +/- 3.15E-08
#
# Iteration 36500/40000
# q = 1.31E-08 +/- 2.38E-08
# dq = 1.53E-09 +/- 5.53E-09
#
# Iteration 37000/40000
# q = 1.28E-08 +/- 2.44E-08
# dq = 1.34E-09 +/- 4.99E-09
#
# Iteration 37500/40000
# q = 1.21E-08 +/- 2.38E-08
# dq = 1.59E-09 +/- 7.17E-09
#
# Iteration 38000/40000
# q = 1.20E-08 +/- 2.13E-08
# dq = 1.45E-09 +/- 5.85E-09
#
# Iteration 38500/40000
# q = 1.23E-08 +/- 2.49E-08
# dq = 1.70E-09 +/- 8.15E-09
#
# Iteration 39000/40000
# q = 1.14E-08 +/- 2.06E-08
# dq = 1.42E-09 +/- 5.77E-09
#
# Iteration 39500/40000
# q = 1.31E-08 +/- 4.06E-08
# dq = 2.55E-09 +/- 3.39E-08
#
# Iteration 40000/40000
# q = 1.32E-08 +/- 2.67E-08
# dq = 2.62E-09 +/- 3.16E-08
# Maximum iteration count reached. Terminating.
# Found 1024 unique fixed points.
# Decomposing Jacobians in a single batch.
# Sorting by Eigenvalue magnitude.

# %%
fpsDT_NODE = analysis_NODE.plot_fps(
    inputs = torch.zeros(3),
    max_iters = 40000,
    learning_rate =5e-3,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fpsDT_NODE = analysis_NODE.plot_fps(
#       2     inputs = torch.zeros(3),
#       3     max_iters = 40000,
#       4     learning_rate =5e-3,
#       5 )
#
# NameError: name 'analysis_NODE' is not defined

# %%
fpsDT_LDS = analysis_LDS.plot_fps(
    inputs = torch.zeros(3),
    max_iters = 40000,
    learning_rate =5e-3,
)
# Out:
# Iteration 500/40000
# q = 8.22E-04 +/- 1.97E-03
# dq = 7.67E-07 +/- 1.58E-05
#
# Iteration 1000/40000
# q = 6.99E-04 +/- 8.57E-04
# dq = 1.47E-07 +/- 2.07E-07
#
# Iteration 1500/40000
# q = 6.18E-04 +/- 7.78E-04
# dq = 1.76E-07 +/- 2.30E-07
#
# Iteration 2000/40000
# q = 5.29E-04 +/- 6.95E-04
# dq = 1.90E-07 +/- 2.41E-07
#
# Iteration 2500/40000
# q = 4.37E-04 +/- 6.12E-04
# dq = 1.95E-07 +/- 2.44E-07
#
# Iteration 3000/40000
# q = 3.48E-04 +/- 5.33E-04
# dq = 1.90E-07 +/- 2.29E-07
#
# Iteration 3500/40000
# q = 2.69E-04 +/- 4.59E-04
# dq = 1.92E-07 +/- 2.74E-07
#
# Iteration 4000/40000
# q = 2.00E-04 +/- 3.91E-04
# dq = 1.76E-07 +/- 3.25E-07
#
# Iteration 4500/40000
# q = 1.45E-04 +/- 3.31E-04
# dq = 1.92E-07 +/- 3.42E-07
#
# Iteration 5000/40000
# q = 1.02E-04 +/- 2.78E-04
# dq = 1.87E-07 +/- 3.57E-07
#
# Iteration 5500/40000
# q = 7.05E-05 +/- 2.31E-04
# dq = 2.14E-07 +/- 4.27E-07
#
# Iteration 6000/40000
# q = 4.79E-05 +/- 1.89E-04
# dq = 2.54E-07 +/- 5.12E-07
#
# Iteration 6500/40000
# q = 3.24E-05 +/- 1.52E-04
# dq = 3.03E-07 +/- 6.61E-07
#
# Iteration 7000/40000
# q = 2.16E-05 +/- 1.19E-04
# dq = 3.00E-07 +/- 6.15E-07
#
# Iteration 7500/40000
# q = 1.43E-05 +/- 8.94E-05
# dq = 3.33E-07 +/- 6.18E-07
#
# Iteration 8000/40000
# q = 9.43E-06 +/- 6.36E-05
# dq = 3.34E-07 +/- 6.32E-07
#
# Iteration 8500/40000
# q = 6.40E-06 +/- 4.19E-05
# dq = 3.62E-07 +/- 6.65E-07
#
# Iteration 9000/40000
# q = 4.30E-06 +/- 2.52E-05
# dq = 3.40E-07 +/- 6.25E-07
#
# Iteration 9500/40000
# q = 2.88E-06 +/- 1.36E-05
# dq = 3.90E-07 +/- 6.88E-07
#
# Iteration 10000/40000
# q = 2.21E-06 +/- 6.86E-06
# dq = 3.62E-07 +/- 6.37E-07
#
# Iteration 10500/40000
# q = 1.91E-06 +/- 3.97E-06
# dq = 3.86E-07 +/- 7.04E-07
#
# Iteration 11000/40000
# q = 1.60E-06 +/- 2.78E-06
# dq = 3.43E-07 +/- 5.86E-07
#
# Iteration 11500/40000
# q = 1.68E-06 +/- 2.84E-06
# dq = 3.89E-07 +/- 7.42E-07
#
# Iteration 12000/40000
# q = 1.43E-06 +/- 2.34E-06
# dq = 3.41E-07 +/- 5.51E-07
#
# Iteration 12500/40000
# q = 1.49E-06 +/- 2.62E-06
# dq = 3.65E-07 +/- 7.06E-07
#
# Iteration 13000/40000
# q = 1.65E-06 +/- 2.99E-06
# dq = 3.78E-07 +/- 7.01E-07
#
# Iteration 13500/40000
# q = 1.66E-06 +/- 2.76E-06
# dq = 3.71E-07 +/- 6.66E-07
#
# Iteration 14000/40000
# q = 1.66E-06 +/- 2.90E-06
# dq = 3.56E-07 +/- 6.11E-07
#
# Iteration 14500/40000
# q = 1.64E-06 +/- 2.71E-06
# dq = 4.06E-07 +/- 7.67E-07
#
# Iteration 15000/40000
# q = 1.57E-06 +/- 2.71E-06
# dq = 3.54E-07 +/- 6.45E-07
#
# Iteration 15500/40000
# q = 1.65E-06 +/- 2.54E-06
# dq = 4.03E-07 +/- 6.57E-07
#
# Iteration 16000/40000
# q = 1.59E-06 +/- 2.71E-06
# dq = 3.75E-07 +/- 6.38E-07
#
# Iteration 16500/40000
# q = 1.56E-06 +/- 2.73E-06
# dq = 3.77E-07 +/- 6.31E-07
#
# Iteration 17000/40000
# q = 1.71E-06 +/- 2.94E-06
# dq = 4.19E-07 +/- 7.64E-07
#
# Iteration 17500/40000
# q = 1.67E-06 +/- 2.85E-06
# dq = 3.70E-07 +/- 6.69E-07
#
# Iteration 18000/40000
# q = 1.58E-06 +/- 2.95E-06
# dq = 3.61E-07 +/- 7.69E-07
#
# Iteration 18500/40000
# q = 1.63E-06 +/- 2.85E-06
# dq = 3.78E-07 +/- 7.11E-07
#
# Iteration 19000/40000
# q = 1.58E-06 +/- 2.79E-06
# dq = 3.59E-07 +/- 6.30E-07
#
# Iteration 19500/40000
# q = 1.67E-06 +/- 2.83E-06
# dq = 3.71E-07 +/- 6.38E-07
#
# Iteration 20000/40000
# q = 1.62E-06 +/- 2.69E-06
# dq = 3.81E-07 +/- 6.98E-07
#
# Iteration 20500/40000
# q = 1.59E-06 +/- 2.74E-06
# dq = 3.60E-07 +/- 6.54E-07
#
# Iteration 21000/40000
# q = 1.61E-06 +/- 2.87E-06
# dq = 3.76E-07 +/- 7.25E-07
#
# Iteration 21500/40000
# q = 1.58E-06 +/- 2.70E-06
# dq = 3.56E-07 +/- 6.50E-07
#
# Iteration 22000/40000
# q = 1.52E-06 +/- 2.67E-06
# dq = 3.31E-07 +/- 6.06E-07
#
# Iteration 22500/40000
# q = 1.75E-06 +/- 2.94E-06
# dq = 4.18E-07 +/- 7.19E-07
#
# Iteration 23000/40000
# q = 1.66E-06 +/- 2.83E-06
# dq = 3.98E-07 +/- 7.60E-07
#
# Iteration 23500/40000
# q = 1.54E-06 +/- 2.69E-06
# dq = 3.75E-07 +/- 6.70E-07
#
# Iteration 24000/40000
# q = 1.58E-06 +/- 2.84E-06
# dq = 3.76E-07 +/- 7.63E-07
#
# Iteration 24500/40000
# q = 1.70E-06 +/- 2.81E-06
# dq = 3.99E-07 +/- 6.79E-07
#
# Iteration 25000/40000
# q = 1.66E-06 +/- 2.83E-06
# dq = 3.98E-07 +/- 6.77E-07
#
# Iteration 25500/40000
# q = 1.57E-06 +/- 2.82E-06
# dq = 3.80E-07 +/- 6.81E-07
#
# Iteration 26000/40000
# q = 1.48E-06 +/- 2.51E-06
# dq = 3.47E-07 +/- 6.26E-07
#
# Iteration 26500/40000
# q = 1.38E-06 +/- 2.43E-06
# dq = 3.27E-07 +/- 5.77E-07
#
# Iteration 27000/40000
# q = 1.47E-06 +/- 2.52E-06
# dq = 3.61E-07 +/- 6.78E-07
#
# Iteration 27500/40000
# q = 1.63E-06 +/- 2.80E-06
# dq = 3.78E-07 +/- 6.68E-07
#
# Iteration 28000/40000
# q = 1.55E-06 +/- 2.67E-06
# dq = 3.75E-07 +/- 6.55E-07
#
# Iteration 28500/40000
# q = 1.51E-06 +/- 2.65E-06
# dq = 3.77E-07 +/- 6.59E-07
#
# Iteration 29000/40000
# q = 1.62E-06 +/- 2.76E-06
# dq = 3.93E-07 +/- 7.25E-07
#
# Iteration 29500/40000
# q = 1.67E-06 +/- 2.78E-06
# dq = 3.96E-07 +/- 6.74E-07
#
# Iteration 30000/40000
# q = 1.56E-06 +/- 2.75E-06
# dq = 3.62E-07 +/- 6.54E-07
#
# Iteration 30500/40000
# q = 1.60E-06 +/- 2.96E-06
# dq = 3.71E-07 +/- 6.43E-07
#
# Iteration 31000/40000
# q = 1.51E-06 +/- 2.61E-06
# dq = 3.59E-07 +/- 6.49E-07
#
# Iteration 31500/40000
# q = 1.47E-06 +/- 2.57E-06
# dq = 3.70E-07 +/- 6.90E-07
#
# Iteration 32000/40000
# q = 1.85E-06 +/- 3.16E-06
# dq = 4.11E-07 +/- 6.85E-07
#
# Iteration 32500/40000
# q = 1.58E-06 +/- 2.66E-06
# dq = 3.80E-07 +/- 7.04E-07
#
# Iteration 33000/40000
# q = 1.63E-06 +/- 2.97E-06
# dq = 4.00E-07 +/- 7.30E-07
#
# Iteration 33500/40000
# q = 1.58E-06 +/- 2.84E-06
# dq = 3.68E-07 +/- 6.76E-07
#
# Iteration 34000/40000
# q = 1.52E-06 +/- 2.59E-06
# dq = 3.22E-07 +/- 6.56E-07
#
# Iteration 34500/40000
# q = 1.52E-06 +/- 2.62E-06
# dq = 3.72E-07 +/- 6.95E-07
#
# Iteration 35000/40000
# q = 1.60E-06 +/- 2.97E-06
# dq = 3.71E-07 +/- 6.54E-07
#
# Iteration 35500/40000
# q = 1.56E-06 +/- 2.70E-06
# dq = 3.75E-07 +/- 6.87E-07
#
# Iteration 36000/40000
# q = 1.62E-06 +/- 2.78E-06
# dq = 3.85E-07 +/- 7.14E-07
#
# Iteration 36500/40000
# q = 1.54E-06 +/- 2.72E-06
# dq = 3.79E-07 +/- 6.58E-07
#
# Iteration 37000/40000
# q = 1.53E-06 +/- 2.71E-06
# dq = 3.74E-07 +/- 6.81E-07
#
# Iteration 37500/40000
# q = 1.59E-06 +/- 2.68E-06
# dq = 3.84E-07 +/- 6.96E-07
#
# Iteration 38000/40000
# q = 1.73E-06 +/- 2.97E-06
# dq = 4.24E-07 +/- 7.74E-07
#
# Iteration 38500/40000
# q = 1.55E-06 +/- 2.59E-06
# dq = 3.91E-07 +/- 7.23E-07
#
# Iteration 39000/40000
# q = 1.65E-06 +/- 2.76E-06
# dq = 4.09E-07 +/- 7.77E-07
#
# Iteration 39500/40000
# q = 1.60E-06 +/- 2.57E-06
# dq = 3.98E-07 +/- 7.02E-07
#
# Iteration 40000/40000
# q = 1.64E-06 +/- 2.80E-06
# dq = 3.86E-07 +/- 7.14E-07
# Maximum iteration count reached. Terminating.
# Found 1024 unique fixed points.
# Decomposing Jacobians in a single batch.
# Sorting by Eigenvalue magnitude.

# %%
lats_TT = an_TT.get_latents().detach().numpy()
lats_GRU = analysis_GRU.get_latents().detach().numpy()
lats_NODE = analysis_NODE.get_latents().detach().numpy()
lats_LDS = analysis_LDS.get_latents().detach().numpy()

plot_model_fps(fpsTT, latents=lats_TT, q_thresh = 1e-7, label = "TT")
plot_model_fps(fpsDT_GRU, latents = lats_GRU, q_thresh = 1e-6, label = "DT_GRU")
plot_model_fps(fpsDT_NODE, latents = lats_NODE, q_thresh = 1e-7, label = "DT_NODE")
plot_model_fps(fpsDT_LDS, latents = lats_LDS, q_thresh = 1e-7, label = "DT_LDS")

# %%
comparison_models = Comparison()
comparison_models.load_analysis(an_TT, reference_analysis=True, group = "TT")
comparison_models.load_analysis(analysis_GRU, group = "GRU")
comparison_models.load_analysis(analysis_NODE, group = "NODE")
comparison_models.load_analysis(analysis_LDS, group = "LDS")
comparison_models.regroup()

# %%
comparison_models.plot_trials_reference(num_trials=2, num_pcs=4)

# %%
lds_fps = analysis_LDS.plot_fps(
    inputs = torch.zeros(3),
    learning_rate = 1e-3,
    n_inits=1024,
    max_iters = 20000,                      
)

# %%
node_fps = analysis_NODE.plot_fps(
    inputs = torch.zeros(3),
    learning_rate = 6e-4,
    n_inits=1024,
    max_iters = 50000,                      
)

# %%
gru_fps = analysis_GRU.plot_fps(
    inputs = torch.zeros(3),
    learning_rate = 6e-4,
    n_inits=1024,
    max_iters = 50000,                      
)

# %%
plot_model_fps(lds_fps, q_thresh = 1e-4)
plot_model_fps(node_fps, q_thresh = 1e-4)
plot_model_fps(gru_fps, q_thresh = 4e-7)
