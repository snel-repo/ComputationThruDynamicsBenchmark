# %%
from ctd.task_modeling.task_env.multi_task_env import MultiTaskWrapper
task_list = [
    # "IntMod1",
    # "IntMod2",
    # "ContextIntMod1",
    # "ContextIntMod2",
    # "ContextIntMultimodal",
    # "Match2Sample",
    # "NonMatch2Sample",
    # "MatchCatPro",
    "MatchCatAnti"
]

tasks = MultiTaskWrapper(task_list=task_list, bin_size = 20, n_timesteps=640, num_targets = 128, noise = 0.1, dynamic_noise = 0.0)

# %%
tasks.plot_tasks()
