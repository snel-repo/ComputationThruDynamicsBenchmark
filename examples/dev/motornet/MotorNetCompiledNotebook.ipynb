# %%
import os
from interpretability.comparison.analysis.tt.tasks.tt_RandomTargetDelay import TT_RandomTargetDelay
from motornet.effector import RigidTendonArm26

# %%
suffix = "RandomTargetDelay_GRU"
filepath1 = (
"/home/csverst/Github/InterpretabilityBenchmark/data/trained_models/task-trained/"
"20240216_RandomTargetDelay_GRU_RNN_Final/max_epochs=2500 seed=0/"
)
plot_path = (
    "/home/csverst/Github/InterpretabilityBenchmark/"
    f"interpretability/comparison/plots/{suffix}/"
)
os.makedirs(plot_path, exist_ok=True)

comp = TT_RandomTargetDelay(run_name=suffix, filepath=filepath1)

# %%
comp.plotTrial(3)
comp.generate_latent_video(align_to="go_cue", dims_by = "hand")
# Out:
# Writing frame 0 of 20
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 comp.plotTrial(3)
# ----> 2 comp.generate_latent_video(align_to="go_cue", dims_by = "hand")
#
# File ~/Github/InterpretabilityBenchmark/interpretability/comparison/analysis/tt/tasks/tt_RandomTargetDelay.py:259, in TT_RandomTargetDelay.generate_latent_video(self, align_to, dims_by, color_by, pre_window, post_window, fps)
#     256 ax.clear()
#     257 for i in range(n_trials_plot):
#     258     ax.scatter(
# --> 259         latents_aligned_pca[i, t, 0],
#     260         latents_aligned_pca[i, t, 1],
#     261         latents_aligned_pca[i, t, 2],
#     262         color=colors[i],
#     263     )
#     264 ax.set_title(f"Time {t-pre_window}")
#     265 ax.set_xlim([-5, 5])  # Set this according to your data range
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed
